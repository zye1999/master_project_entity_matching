# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import collections

# %%
def withStar(string):
  if string=='':
    return '';
  else:
    string = string.replace(" ","**")
    return '**'+string[:]+'**'

# %%
def grams(string,num):
    string=withStar(string)
    begin=len(string)-num;
    token=[];
    for i in range(begin+1):
        a=[];
        a=string[i:i+3]
        token.append(a);
    return token;

# %%
def overlap(string1,string2)->int:
    s1=grams(string1,3);
    s2=grams(string2,3);
    common_elements = list(set(s1).intersection(set(s2)));
    lc=len(common_elements);
    m=min(len(s1),len(s2));
    if m==0: 
        return 0;
    else:
        sim1=lc/m;
        return sim1;

# %%
def jaccard(string1,string2):
    s1=grams(string1,3);
    s2=grams(string2,3);
    common_elements = list(set(s1).intersection(set(s2)));
    lc=len(common_elements);
    union_elements=list(set(s1).union(set(s2)));
    lu=len(union_elements);
    if lu==0:
        return 0;
    else:
        sim2 = lc/lu;
        return sim2;

# %%
def dice(string1,string2):
    s1=grams(string1,3);
    s2=grams(string2,3);
    common_elements = list(set(s1).intersection(set(s2)));
    lc=len(common_elements);
    if len(s1)+len(s2)==0:
        return 0;
    else:
        sim3=2*lc/(len(s1)+len(s2));
        return sim3;

# %%
def accuracy(mark_real,mark_test):
    sum = 0
    for i in range(len(mark_real)):
        if mark_real[i]==mark_test[i]:
            sum=sum+1
        else:
            continue
    return sum/len(mark_test)

# %%
train = pd.read_csv("train.tsv", sep="\t")

# %%
train
# Out:
#          idx                                          text_left  \
# 0          0  lg 24 ' lds4821ww semi integrated built in whi...
# 1          1  speck seethru clear hard shell case for macboo...
# 2          2  denon blu-ray disc dvd/cd player dvd3800bdci 1...
# 3          3  panasonic dect 6.0 expandable digital cordless...
# 4          4  sony silver minidv handycam camcorder dcrhc52 ...
# ...      ...                                                ...
# 43717  43717  gear head wireless optical tilt-wheel mouse re...
# 43718  43718  cables to go usb 2.0 a b cable 9 feet white ca...
# 43719  43719  epson t060320 ink cartridge magenta printers e...
# 43720  43720  crown industrial deck plate antifatigue vinyl ...
# 43721  43721  cables unlimited 3 svga video cable hdb15 male...
#
#                                               text_right  label
# 0               lg ldf6920bb fully integrated dishwasher      0
# 1      speck products seethru case for apple 13 ' mac...      0
# 2      denon dvd-2930ci dvd player dvd2930ci dvd + rw...      0
# 3      panasonic kx-tg1032s dual handset digital cord...      0
# 4         sony minidv head cleaner dvm12cld head cleaner      0
# ...                                                  ...    ...
# 43717  gear head 2.4 ghz mini wireless desktop and op...      0
# 43718  cables unlimited usb-5010-03m usb 2.0 a to b c...      0
# 43719  epson 78 yellow ink cartridge t078420 t078420 ...      0
# 43720  new-crown cd0035db - industrial deck plate ant...      0
# 43721  cables unlimited pcm-2240-99 svga video cable ...      0
#
# [43722 rows x 4 columns]

# %%
train_label=train['label']
sum_label_one=0
for i in range(len(train_label)):
    if(train_label[i]==1):
        sum_label_one=sum_label_one +1
sum_label_one
# Out:
# 6508

# %%
question1=train['text_left']
question2=train['text_right']
mark=train['label']

# %%
#calculate the overlap coefficient
overlap_coefficient=[]
for i in range(len(question1)):
    overlap_coefficient.append(overlap(question1[i],question2[i]))

# %%
#get the equal coefficient
equal_overlap=[]
for i in range(len(overlap_coefficient)):
    if mark[i]==1:
        equal_overlap.append(overlap_coefficient[i])
#         print("The two sentence is equal, overlap coefficient is:",overlap_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
#get the equal coefficient
inequal_overlap=[]
for i in range(len(overlap_coefficient)):
    if mark[i]==0:
        inequal_overlap.append(overlap_coefficient[i])
#         print("The two sentence is not equal, overlap coefficient is:",overlap_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
thershold=[]
for i in range(1,100):
    thershold.append(0.01*i)

# %%
from sklearn.metrics import f1_score
fscore_overlap_train=[]
for i in range(len(thershold)):
    mark_train_pred=[]
    for j in range(len(overlap_coefficient)):
        if overlap_coefficient[j] >= thershold[i]:
            mark_train_pred.append(1)
        else: mark_train_pred.append(0)
    fscore_overlap_train.append(f1_score(mark,mark_train_pred,average='binary'))
    print("Thershold is: {:.2f}".format(thershold[i]))
    print("current max f-score is: {}".format(max(fscore_overlap_train)))
    print("thershold of the max fscore is: {}".format(fscore_overlap_train.index(max(fscore_overlap_train))))#0.68
# Out:
# Thershold is: 0.01
# current max f-score is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.02
# current max f-score is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.03
# current max f-score is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.04
# current max f-score is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.05
# current max f-score is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.06
# current max f-score is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.07
# current max f-score is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.08
# current max f-score is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.09
# current max f-score is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.10
# current max f-score is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.11
# current max f-score is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.12
# current max f-score is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.13
# current max f-score is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.14
# current max f-score is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.15
# current max f-score is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.16
# current max f-score is: 0.2591331700810289
# thershold of the max fscore is: 15
# Thershold is: 0.17
# current
train=[]
for i in range(len(thershold)):
    mark_train_pred=[]
    for j in range(len(jaccard_coefficient)):
        if jaccard_coefficient[j] >= thershold[i]:
            mark_train_pred.append(1)
        else: mark_train_pred.append(0)
    fscore_jaccard_train.append(f1_score(mark,mark_train_pred,average='binary'))
    print("Thershold is: {:.2f}".format(thershold[i]))
    print("current max fscore is: {}".format(max(fscore_jaccard_train)))
    print("thershold of the max fscore is: {}".format(fscore_jaccard_train.index(max(fscore_jaccard_train))))#0.52
# Out:
# Thershold is: 0.01
# current max fscore is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.02
# current max fscore is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.03
# current max fscore is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.04
# current max fscore is: 0.2591280111487159
# thershold of the max fscore is: 0
# Thershold is: 0.05
# current max fscore is: 0.2591331700810289
# thershold of the max fscore is: 4
# Thershold is: 0.06
# current max fscore is: 0.2591331700810289
# thershold of the max fscore is: 4
# Thershold is: 0.07
# current max fscore is: 0.2591331700810289
# thershold of the max fscore is: 4
# Thershold is: 0.08
# current max fscore is: 0.2591426977930046
# thershold of the max fscore is: 7
# Thershold is: 0.09
# current max fscore is: 0.2595407664532088
# thershold of the max fscore is: 8
# Thershold is: 0.10
# current max fscore is: 0.25992087279702675
# thershold of the max fscore is: 9
# Thershold is: 0.11
# current max fscore is: 0.2605629570269458
# thershold of the max fscore is: 10
# Thershold is: 0.12
# current max fscore is: 0.26158520635048393
# thershold of the max fscore is: 11
# Thershold is: 0.13
# current max fscore is: 0.26274478070885254
# thershold of the max fscore is: 12
# Thershold is: 0.14
# current max fscore is: 0.26422938191599926
# thershold of the max fscore is: 13
# Thershold is: 0.15
# current max fscore is: 0.2665021084027564
# thershold of the max fscore is: 14
# Thershold is: 0.16
# current max fscore is: 0.269185114225619
# thershold of the max fscore is: 15
# Thershold is: 0.17
# current max fscore is: 0.2730005504043355
# thershold of the max fscore is: 16
# Thershold is: 0.18
# current max fscore is: 0.2779014720823155
# thershold of the max fscore is: 17
# Thershold is: 0.19
# current max fscore is: 0.28381433701290065
# thershold of the max fscore is: 18
# Thershold is: 0.20
# current max fscore is: 0.29075572780120823
# thershold of the max fscore is: 19
# Thershold is: 0.21
# current max fscore is: 0.30082456639181127
# thershold of the max fscore is: 20
# Thershold is: 0.22
# current max fscore is: 0.31225257323832145
# thershold of the max fscore is: 21
# Thershold is: 0.23
# current max fscore is: 0.3256055183859759
# thershold of the max fscore is: 22
# Thershold is: 0.24
# current max fscore is: 0.3417022207635926
# thershold of the max fscore is: 23
# Thershold is: 0.25
# current max fscore is: 0.3578232467121356
# thershold of the max fscore is: 24
# Thershold is: 0.26
# current max fscore is: 0.37857558941656194
# thershold of the max fscore is: 25
# Thershold is: 0.27
# current max fscore is: 0.39833701442120306
# thershold of the max fscore is: 26
# Thershold is: 0.28
# current max fscore is: 0.4181431122098612
# thershold of the max fscore is: 27
# Thershold is: 0.29
# current max fscore is: 0.44063968525736774
# thershold of the max fscore is: 28
# Thershold is: 0.30
# current max fscore is: 0.4612490883267437
# thershold of the max fscore is: 29
# Thershold is: 0.31
# current max fscore is: 0.4829849295089937
# thershold of the max fscore is: 30
# Thershold is: 0.32
# current max fscore is: 0.5050522276700063
# thershold of the max fscore is: 31
# Thershold is: 0.33
# current max fscore is: 0.5244907964522887
# thershold of the max fscore is: 32
# Thershold is: 0.34
# current max fscore is: 0.5425101214574899
# thershold of the max fscore is: 33
# Thershold is: 0.35
# current max fscore is: 0.563069871763616
# thershold of the max fscore is: 34
# Thershold is: 0.36
# current max fscore is: 0.5808935264917435
# thershold of the max fscore is: 35
# Thershold is: 0.37
# current max fscore is: 0.5989895800442059
# thershold of the max fscore is: 36
# Thershold is: 0.38
# current max fscore is: 0.6156449587859599
# thershold of the max fscore is: 37
# Thershold is: 0.39
# current max fscore is: 0.6309422870386071
# thershold of the max fscore is: 38
# Thershold is: 0.40
# current max fscore is: 0.6447353044291224
# thershold of the max fscore is: 39
# Thershold is: 0.41
# current max fscore is: 0.6602870813397129
# thershold of the max fscore is: 40
# Thershold is: 0.42
# current max fscore is: 0.6751520471502915
# thershold of the max fscore is: 41
# Thershold is: 0.43
# current max fscore is: 0.6892750616003113
# thershold of the max fscore is: 42
# Thershold is: 0.44
# current max fscore is: 0.7025689055392026
# thershold of the max fscore is: 43
# Thershold is: 0.45
# current max fscore is: 0.7117011763087295
# thershold of the max fscore is: 44
# Thershold is: 0.46
# current max fscore is: 0.7216961130742049
# thershold of the max fscore is: 45
# Thershold is: 0.47
# current max fscore is: 0.7297277676950998
# thershold of the max fscore is: 46
# Thershold is: 0.48
# current max fscore is: 0.7346484722634232
# thershold of the max fscore is: 47
# Thershold is: 0.49
# current max fscore is: 0.7372894217635453
# thershold of the max fscore is: 48
# Thershold is: 0.50
# current max fscore is: 0.7400092578305817
# thershold of the max fscore is: 49
# Thershold is: 0.51
# current max fscore is: 0.7426086956521739
# thershold of the max fscore is: 50
# Thershold is: 0.52
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.53
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.54
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.55
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.56
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.57
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.58
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.59
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.60
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.61
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.62
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.63
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.64
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.65
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.66
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.67
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.68
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.69
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.70
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.71
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.72
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.73
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.74
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.75
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.76
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.77
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.78
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.79
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.80
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.81
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.82
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.83
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.84
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.85
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.86
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.87
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.88
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.89
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.90
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.91
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.92
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.93
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.94
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.95
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.96
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.97
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.98
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51
# Thershold is: 0.99
# current max fscore is: 0.7430963690524113
# thershold of the max fscore is: 51

# %%
#calculate the dice's coefficient
dice_coefficient=[]
for i in range(len(question1)):
    dice_coefficient.append(dice(question1[i],question2[i]))

# %%
#get the equal coefficient
equal_dice=[]
for i in range(len(dice_coefficient)):
    if mark[i]==1:
        equal_dice.append(dice_coefficient[i])
#         print("The two sentence is equal, overlap coefficient is:",dice_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
#get the inequal coefficient
inequal_dice=[]
for i in range(len(dice_coefficient)):
    if mark[i]==0:
        inequal_dice.append(dice_coefficient[i])
#         print("The two sentence is not equal, overlap coefficient is:",dice_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
fscore_dice_train=[]
for i in range(len(thershold)):
    mark_train_pred=[]
    for j in range(len(dice_coefficient)):
        if dice_coefficient[j] >= thershold[i]:
            mark_train_pred.append(1)
        else: mark_train_pred.append(0)
    fscore_dice_train.append(f1_score(mark,mark_train_pred,average='binary'))
    print("Thershold is: {:.2f}".format(thershold[i]))
    print("current
# current max fscore is: 0.7315468549422336
# thershold of the max fscore is: 56
# Thershold is: 0.99
# current max fscore is: 0.7315468549422336
# thershold of the max fscore is: 56

# %%
test = pd.read_csv("test.tsv", sep="\t")

# %%
test
# Out:
#          idx                                          text_left  \
# 0          0  sony pink cyber-shot 7.2 megapixel digital cam...
# 1          1  lg 2.0 cu . ft. over-the-range white microwave...
# 2          2  panasonic black 8.5 ' portable dvd player dvdl...
# 3          3  sony bravia theater black micro system davis50...
# 4          4  panasonic dect 6.0 expandable digital cordless...
# ...      ...                                                ...
# 14577  14577  lexar platinum ii 16gb sd sdhc memory card lex...
# 14578  14578  da-lite video spectra 1.5 advantage manual wit...
# 14579  14579  da-lite da-plex unframed rear projection scree...
# 14580  14580  rca cassette adapter mp3 accessories ah760r 12...
# 14581  14581  tp-link network tl-sg1024d 24 port gigabit des...
#
#                                               text_right  label
# 0      olympus fe-360 digital camera pink 226540 8 me...      0
# 1      maytag 2.0 cu . ft. over-the-range microwave oven      0
# 2      toshiba sd-p71s portable dvd player toshiba sd...      0
# 3      sony bravia dav-is50 / b home theater system d...      1
# 4      panasonic kx-tg9342t cordless phone 1 x phone ...      0
# ...                                                  ...    ...
# 14577  lexar lcf4gbbsbna200 platinum ii 4 gb 200x com...      0
# 14578  da-lite advantage manual with csr - projection...      0
# 14579  da-lite 27651 da-glas deluxe rear projection s...      0
# 14580  rca vca115 vhs-c cassette adapter blank media ...      0
# 14581  gigabit desktop switch 24port 24 10 100 1000 m...      1
#
# [14582 rows x 4 columns]

# %%
question1_test=test['text_left']
question2_test=test['text_right']
mark_test=test['label']

# %%
test_overlap=[]
test_jaccard=[]
test_dice=[]
for i in range(len(question1_test)):
    test_overlap.append(overlap(question1_test[i],question2_test[i]))
    test_jaccard.append(jaccard(question1_test[i],question2_test[i]))
    test_dice.append(dice(question1_test[i],question2_test[i]))

# %%
def calculate_is_duplicate(coefficient,thershold):
    mark=[]
    for i in range(len(coefficient)):
        if coefficient[i] >= thershold:
            mark.append(1)
        else:
            mark.append(0)
    return mark

# %%
mark_overlap_f_test=calculate_is_duplicate(test_overlap,0.68)
print("overlap coefficient fscore:")
print(f1_score(mark_test,mark_overlap_f_test,average='binary'))
# Out:
# overlap coefficient fscore:
# 0.7139639639639639

# %%
mark_jaccard_f_test=calculate_is_duplicate(test_jaccard,0.52)
print("jaccard coefficient fscore:")
print(f1_score(mark_test,mark_jaccard_f_test,average='binary'))
# Out:
# jaccard coefficient fscore:
# 0.7430791646430305

# %%
mark_dice_f_test=calculate_is_duplicate(test_dice,0.57)
print("dice coefficient fscore:")
print(f1_score(mark_test,mark_dice_f_test,average='binary'))
# Out:
# dice coefficient fscore:
# 0.7314949201741654

# %%
# use a classifier to predict the result
X_train=[]
X_test=[]
for i in range(len(question1)):
    co=(overlap_coefficient[i], jaccard_coefficient[i], dice_coefficient[i])
    X_train.append(co)
y_train=mark
for i in range(len(question1_test)):
    co=(test_overlap[i], test_jaccard[i], test_dice[i])
    X_test.append(co)
y_test=mark_test

# %%
#use KNeighbors Classifier
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=1)
model=knn.fit(X_train,y_train)
y_pred=knn.predict(X_test)
print("Test set predictions:\n{}".format(y_pred))
print("Test set score: {:.2f}".format(np.mean(y_pred == y_test)))
print("Test set score: {:.2f}".format(knn.score(X_test, y_test)))
# Out:
# Test set predictions:
# [0 1 0 ... 0 0 1]
# Test set score: 0.91
# Test set score: 0.91
