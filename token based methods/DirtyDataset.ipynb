# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import collections

# %%
def withStar(string):
  if string=='':
    return '';
  else:
    string = string.replace(" ","**")
    return '**'+string[:]+'**'

# %%
def grams(string,num):
    string=withStar(string)
    begin=len(string)-num;
    token=[];
    for i in range(begin+1):
        a=[];
        a=string[i:i+3]
        token.append(a);
    return token;

# %%
def overlap(string1,string2)->int:
    s1=grams(string1,3);
    s2=grams(string2,3);
    common_elements = list(set(s1).intersection(set(s2)));
    lc=len(common_elements);
    m=min(len(s1),len(s2));
    if m==0: 
        return 0;
    else:
        sim1=lc/m;
        return sim1;

# %%
def jaccard(string1,string2):
    s1=grams(string1,3);
    s2=grams(string2,3);
    common_elements = list(set(s1).intersection(set(s2)));
    lc=len(common_elements);
    union_elements=list(set(s1).union(set(s2)));
    lu=len(union_elements);
    if lu==0:
        return 0;
    else:
        sim2 = lc/lu;
        return sim2;

# %%
def dice(string1,string2):
    s1=grams(string1,3);
    s2=grams(string2,3);
    common_elements = list(set(s1).intersection(set(s2)));
    lc=len(common_elements);
    if len(s1)+len(s2)==0:
        return 0;
    else:
        sim3=2*lc/(len(s1)+len(s2));
        return sim3;

# %%
def accuracy(mark_real,mark_test):
    sum = 0
    for i in range(len(mark_real)):
        if mark_real[i]==mark_test[i]:
            sum=sum+1
        else:
            continue
    return sum/len(mark_test)

# %%
train = pd.read_csv("train.tsv", sep="\t")

# %%
train
# Out:
#          idx                                          text_left  \
# 0          0  Illusion ( feat . Echosmith ) Zedd True Colors...
# 1          1  I 'm a Machine ( feat . Crystal Nicole and Tyr...
# 2          2  Silver and Gold 3:33 Little Big Town Pain Kill...
# 3          3  Dangerous ( feat . Sam Martin ) [ Robin Schulz...
# 4          4  True Colors ( feat . Nicki Minaj ) Wiz Khalifa...
# ...      ...                                                ...
# 31100  31100  gear head wireless optical tilt-wheel mouse re...
# 31101  31101  cables to go usb 2.0 a b cable 9 feet white ca...
# 31102  31102  epson t060320 ink cartridge magenta printers e...
# 31103  31103  crown industrial deck plate antifatigue vinyl ...
# 31104  31104  cables unlimited 3 svga video cable hdb15 male...
#
#                                               text_right  label
# 0      Transmission [ feat . X Ambassadors ] Dance & ...      0
# 1      I Can Only Imagine ( feat . Chris Brown & Lil ...      0
# 2      Silver And Gold Little Big Town Country ( C ) ...      1
# 3      I 'll Keep Loving you ( feat . Birdy & Jaymes ...      0
# 4      Still Down ( feat . Chevy Woods & Ty Dolla $ i...      0
# ...                                                  ...    ...
# 31100  gear head 2.4 ghz mini wireless desktop and op...      0
# 31101  cables unlimited usb-5010-03m usb 2.0 a to b c...      0
# 31102  epson 78 yellow ink cartridge t078420 t078420 ...      0
# 31103  new-crown cd0035db - industrial deck plate ant...      0
# 31104  cables unlimited pcm-2240-99 svga video cable ...      0
#
# [31105 rows x 4 columns]

# %%
train_label=train['label']
sum_label_one=0
for i in range(len(train_label)):
    if(train_label[i]==1):
        sum_label_one=sum_label_one +1
sum_label_one
# Out:
# 5193

# %%
question1=train['text_left']
question2=train['text_right']
mark=train['label']

# %%
#calculate the overlap coefficient
overlap_coefficient=[]
for i in range(len(question1)):
    overlap_coefficient.append(overlap(question1[i],question2[i]))

# %%
#get the equal coefficient
equal_overlap=[]
for i in range(len(overlap_coefficient)):
    if mark[i]==1:
        equal_overlap.append(overlap_coefficient[i])
#         print("The two sentence is equal, overlap coefficient is:",overlap_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
#get the equal coefficient
inequal_overlap=[]
for i in range(len(overlap_coefficient)):
    if mark[i]==0:
        inequal_overlap.append(overlap_coefficient[i])
#         print("The two sentence is not equal, overlap coefficient is:",overlap_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
thershold=[]
for i in range(1,100):
    thershold.append(0.01*i)

# %%
from sklearn.metrics import f1_score
fscore_overlap_train=[]
for i in range(len(thershold)):
    mark_train_pred=[]
    for j in range(len(overlap_coefficient)):
        if overlap_coefficient[j] >= thershold[i]:
            mark_train_pred.append(1)
        else: mark_train_pred.append(0)
    fscore_overlap_train.append(f1_score(mark,mark_train_pred,average='binary'))
    print("Thershold is: {:.2f}".format(thershold[i]))
    print("current max f-score is: {}".format(max(fscore_overlap_train)))
    print("thershold of the max fscore is: {}".format(fscore_overlap_train.index(max(fscore_overlap_train))))#0.68
    overlap_threshold = 0.01*((fscore_overlap_train.index(max(fscore_overlap_train)))+1)
# Out:
# Thershold is: 0.01
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.02
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.03
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.04
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.05
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.06
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.07
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.08
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.09
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.10
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.11
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.12
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.13
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.14
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.15
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.16
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.17
# current max f-score is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.18
# current max f-score is: 0.2861393503595338
# thershold of the max fscore is: 17
# Thershold is: 0.19
# current max f-score is: 0.28616300214911555
# thershold of the max fscore is: 18
# Thershold is: 0.20
# current max f-score is: 0.2861945439515018
# thershold of the max fscore is: 19
# Thershold is: 0.21
# current max f-score is: 0.2863681482298445
# thershold of the max fscore is: 20
# Thershold is: 0.22
# current max f-score is: 0.28652615316707125
# thershold of the max fscore is: 21
# Thershold is: 0.23
# current max f-score is: 0.28681892242688684
# thershold of the max fscore is: 22
# Thershold is: 0.24
# current max f-score is: 0.287294957262593
# thershold of the max fscore is: 23
# Thershold is: 0.25
# current max f-score is: 0.2877008310249307
# thershold of the max fscore is: 24
# Thershold is: 0.26
# current max f-score is: 0.28845298955323406
# thershold of the max fscore is: 25
# Thershold is: 0.27
# current max f-score is: 0.2895551526983684
# thershold of the max fscore is: 26
# Thershold is: 0.28
# current max f-score is: 0.2911303665068282
# thershold of the max fscore is: 27
# Thershold is: 0.29
# current max f-score is: 0.2931940129906806
# thershold of the max fscore is: 28
# Thershold is: 0.30
# current max f-score is: 0.29564424693046176
# thershold of the max fscore is: 29
# Thershold is: 0.31
# current max f-score is: 0.2986751152073733
# thershold of the max fscore is: 30
# Thershold is: 0.32
# current max f-score is: 0.30265884481802524
# thershold of the max fscore is: 31
# Thershold is: 0.33
# current max f-score is: 0.307715142339775
# thershold of the max fscore is: 32
# Thershold is: 0.34
# current max f-score is: 0.31403556605774186
# thershold of the max fscore is: 33
# Thershold is: 0.35
# current max f-score is: 0.32088211608746825
# thershold of the max fscore is: 34
# Thershold is: 0.36
# current max f-score is: 0.32897160642825385
# thershold of the max fscore is: 35
# Thershold is: 0.37
# current max f-score is: 0.3385772690106296
# thershold of the max fscore is: 36
# Thershold is: 0.38
# current max f-score is: 0.34979549065341586
# thershold of the max fscore is: 37
# Thershold is: 0.39
# current max f-score is: 0.36128491034289906
# thershold of the max fscore is: 38
# Thershold is: 0.40
# current max f-score is: 0.3733873007842145
# thershold of the max fscore is: 39
# Thershold is: 0.41
# current max f-score is: 0.38947209425269996
# thershold of the max fscore is: 40
# Thershold is: 0.42
# current max f-score is: 0.4071482228284505
# thershold of the max fscore is: 41
# Thershold is: 0.43
# current max f-score is: 0.4243525670149932
# thershold of the max fscore is: 42
# Thershold is: 0.44
# current max f-score is: 0.4433880726015558
# thershold of the max fscore is: 43
# Thershold is: 0.45
# current max f-score is: 0.4645612124512206
# thershold of the max fscore is: 44
# Thershold is: 0.46
# current max f-score is: 0.48592085235920845
# thershold of the max fscore is: 45
# Thershold is: 0.47
# current max f-score is: 0.5081713229046929
# thershold of the max fscore is: 46
# Thershold is: 0.48
# current max f-score is: 0.5295686274509803
# thershold of the max fscore is: 47
# Thershold is: 0.49
# current max f-score is: 0.5501667669090711
# thershold of the max fscore is: 48
# Thershold is: 0.50
# current max f-score is: 0.5668552036199095
# thershold of the max fscore is: 49
# Thershold is: 0.51
# current max f-score is: 0.596067650750015
# thershold of the max fscore is: 50
# Thershold is: 0.52
# current max f-score is: 0.6162855896828858
# thershold of the max fscore is: 51
# Thershold is: 0.53
# current max f-score is: 0.6365878992469488
# thershold of the max fscore is: 52
# Thershold is: 0.54
# current max f-score is: 0.6586818243334687
# thershold of the max fscore is: 53
# Thershold is: 0.55
# current max f-score is: 0.6771664566708666
# thershold of the max fscore is: 54
# Thershold is: 0.56
# current max f-score is: 0.6918793839033914
# thershold of the max fscore is: 55
# Thershold is: 0.57
# current max f-score is: 0.7076854066985647
# thershold of the max fscore is: 56
# Thershold is: 0.58
# current max f-score is: 0.7242868157286045
# thershold of the max fscore is: 57
# Thershold is: 0.59
# current max f-score is: 0.73678370452564
# thershold of the max fscore is: 58
# Thershold is: 0.60
# current max f-score is: 0.7461232442965009
# thershold of the max fscore is: 59
# Thershold is: 0.61
# current max f-score is: 0.7575177009579341
# thershold of the max fscore is: 60
# Thershold is: 0.62
# current max f-score is: 0.7662658821522981
# thershold of the max fscore is: 61
# Thershold is: 0.63
# current max f-score is: 0.7721960579103437
# thershold of the max fscore is: 62
# Thershold is: 0.64
# current max f-score is: 0.7734069063723744
# thershold of the max fscore is: 63
# Thershold is: 0.65
# current max f-score is: 0.7770596267637688
# thershold of the max fscore is: 64
# Thershold is: 0.66
# current max f-score is: 0.7799163179916317
# thershold of the max fscore is: 65
# Thershold is: 0.67
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.68
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.69
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.70
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.71
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.72
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.73
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.74
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.75
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.76
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.77
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.78
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.79
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.80
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.81
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.82
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.83
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.84
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.85
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.86
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.87
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.88
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.89
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.90
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.91
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.92
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.93
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.94
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.95
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.96
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.97
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.98
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66
# Thershold is: 0.99
# current max f-score is: 0.7799981058812389
# thershold of the max fscore is: 66

# %%
#calculate the jaccard coefficient
jaccard_coefficient=[]
for i in range(len(question1)):
    jaccard_coefficient.append(jaccard(question1[i],question2[i]))

# %%
#get the equal coefficient
equal_jaccard=[]
for i in range(len(jaccard_coefficient)):
    if mark[i]==1:
        equal_jaccard.append(jaccard_coefficient[i])
#         print("The two sentence is equal, overlap coefficient is:",jaccard_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
#get the inequal coefficient
inequal_jaccard=[]
for i in range(len(jaccard_coefficient)):
    if mark[i]==0:
        inequal_jaccard.append(jaccard_coefficient[i])
#         print("The two sentence is not equal, overlap coefficient is:",jaccard_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
from sklearn.metrics import f1_score
fscore_jaccard_train=[]
for i in range(len(thershold)):
    mark_train_pred=[]
    for j in range(len(jaccard_coefficient)):
        if jaccard_coefficient[j] >= thershold[i]:
            mark_train_pred.append(1)
        else: mark_train_pred.append(0)
    fscore_jaccard_train.append(f1_score(mark,mark_train_pred,average='binary'))
    print("Thershold is: {:.2f}".format(thershold[i]))
    print("current max fscore is: {}".format(max(fscore_jaccard_train)))
    print("thershold of the max fscore is: {}".format(fscore_jaccard_train.index(max(fscore_jaccard_train))))#0.52
    jaccard_threshold = 0.01*((fscore_jaccard_train.index(max(fscore_jaccard_train)))+1)
# Out:
# Thershold is: 0.01
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.02
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.03
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.04
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.05
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.06
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.07
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.08
# current max fscore is: 0.2861393503595338
# thershold of the max fscore is: 7
# Thershold is: 0.09
# current max fscore is: 0.28616300214911555
# thershold of the max fscore is: 8
# Thershold is: 0.10
# current max fscore is: 0.28623398098387764
# thershold of the max fscore is: 9
# Thershold is: 0.11
# current max fscore is: 0.28651034482758625
# thershold of the max fscore is: 10
# Thershold is: 0.12
# current max fscore is: 0.28685853173507153
# thershold of the max fscore is: 11
# Thershold is: 0.13
# current max fscore is: 0.2873108523057346
# thershold of the max fscore is: 12
# Thershold is: 0.14
# current max fscore is: 0.28806789815277084
# thershold of the max fscore is: 13
# Thershold is: 0.15
# current max fscore is: 0.28923916675949646
# thershold of the max fscore is: 14
# Thershold is: 0.16
# current max fscore is: 0.2910140379388607
# thershold of the max fscore is: 15
# Thershold is: 0.17
# current max fscore is: 0.29381793478260876
# thershold of the max fscore is: 16
# Thershold is: 0.18
# current max fscore is: 0.29790775765577016
# thershold of the max fscore is: 17
# Thershold is: 0.19
# current max fscore is: 0.303778942130375
# thershold of the max fscore is: 18
# Thershold is: 0.20
# current max fscore is: 0.31078895345354335
# thershold of the max fscore is: 19
# Thershold is: 0.21
# current max fscore is: 0.3208638881153501
# thershold of the max fscore is: 20
# Thershold is: 0.22
# current max fscore is: 0.3332690329218107
# thershold of the max fscore is: 21
# Thershold is: 0.23
# current max fscore is: 0.3479049153908138
# thershold of the max fscore is: 22
# Thershold is: 0.24
# current max fscore is: 0.3653941147413732
# thershold of the max fscore is: 23
# Thershold is: 0.25
# current max fscore is: 0.3826987060998152
# thershold of the max fscore is: 24
# Thershold is: 0.26
# current max fscore is: 0.4057788944723618
# thershold of the max fscore is: 25
# Thershold is: 0.27
# current max fscore is: 0.4280739573833015
# thershold of the max fscore is: 26
# Thershold is: 0.28
# current max fscore is: 0.45097524709175196
# thershold of the max fscore is: 27
# Thershold is: 0.29
# current max fscore is: 0.4756976529292182
# thershold of the max fscore is: 28
# Thershold is: 0.30
# current max fscore is: 0.4986891931255462
# thershold of the max fscore is: 29
# Thershold is: 0.31
# current max fscore is: 0.5224215246636771
# thershold of the max fscore is: 30
# Thershold is: 0.32
# current max fscore is: 0.5471546887523377
# thershold of the max fscore is: 31
# Thershold is: 0.33
# current max fscore is: 0.5678324793940743
# thershold of the max fscore is: 32
# Thershold is: 0.34
# current max fscore is: 0.5888566453859547
# thershold of the max fscore is: 33
# Thershold is: 0.35
# current max fscore is: 0.6123315936400048
# thershold of the max fscore is: 34
# Thershold is: 0.36
# current max fscore is: 0.6322410214478899
# thershold of the max fscore is: 35
# Thershold is: 0.37
# current max fscore is: 0.6516897831607736
# thershold of the max fscore is: 36
# Thershold is: 0.38
# current max fscore is: 0.6707136112235261
# thershold of the max fscore is: 37
# Thershold is: 0.39
# current max fscore is: 0.6875043508527672
# thershold of the max fscore is: 38
# Thershold is: 0.40
# current max fscore is: 0.7027492642308519
# thershold of the max fscore is: 39
# Thershold is: 0.41
# current max fscore is: 0.7213723451656023
# thershold of the max fscore is: 40
# Thershold is: 0.42
# current max fscore is: 0.7391604635100912
# thershold of the max fscore is: 41
# Thershold is: 0.43
# current max fscore is: 0.7551440329218106
# thershold of the max fscore is: 42
# Thershold is: 0.44
# current max fscore is: 0.7699828892691274
# thershold of the max fscore is: 43
# Thershold is: 0.45
# current max fscore is: 0.7805611222444889
# thershold of the max fscore is: 44
# Thershold is: 0.46
# current max fscore is: 0.7911073108165882
# thershold of the max fscore is: 45
# Thershold is: 0.47
# current max fscore is: 0.8004553016373348
# thershold of the max fscore is: 46
# Thershold is: 0.48
# current max fscore is: 0.8068293555019218
# thershold of the max fscore is: 47
# Thershold is: 0.49
# current max fscore is: 0.8117690058479533
# thershold of the max fscore is: 48
# Thershold is: 0.50
# current max fscore is: 0.8159019134311722
# thershold of the max fscore is: 49
# Thershold is: 0.51
# current max fscore is: 0.8206883437915955
# thershold of the max fscore is: 50
# Thershold is: 0.52
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.53
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.54
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.55
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.56
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.57
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.58
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.59
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.60
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.61
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.62
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.63
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.64
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.65
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.66
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.67
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.68
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.69
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.70
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.71
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.72
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.73
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.74
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.75
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.76
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.77
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.78
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.79
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.80
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.81
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.82
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.83
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.84
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.85
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.86
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.87
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.88
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.89
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.90
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.91
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.92
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.93
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.94
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.95
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.96
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.97
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.98
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51
# Thershold is: 0.99
# current max fscore is: 0.8223360061829775
# thershold of the max fscore is: 51

# %%
#calculate the dice's coefficient
dice_coefficient=[]
for i in range(len(question1)):
    dice_coefficient.append(dice(question1[i],question2[i]))

# %%
#get the equal coefficient
equal_dice=[]
for i in range(len(dice_coefficient)):
    if mark[i]==1:
        equal_dice.append(dice_coefficient[i])
#         print("The two sentence is equal, overlap coefficient is:",dice_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
#get the inequal coefficient
inequal_dice=[]
for i in range(len(dice_coefficient)):
    if mark[i]==0:
        inequal_dice.append(dice_coefficient[i])
#         print("The two sentence is not equal, overlap coefficient is:",dice_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
fscore_dice_train=[]
for i in range(len(thershold)):
    mark_train_pred=[]
    for j in range(len(dice_coefficient)):
        if dice_coefficient[j] >= thershold[i]:
            mark_train_pred.append(1)
        else: mark_train_pred.append(0)
    fscore_dice_train.append(f1_score(mark,mark_train_pred,average='binary'))
    print("Thershold is: {:.2f}".format(thershold[i]))
    print("current max fscore is: {}".format(max(fscore_dice_train)))
    print("thershold of the max fscore is: {}".format(fscore_dice_train.index(max(fscore_dice_train))))#0.57
    dice_threshold = 0.01*((fscore_dice_train.index(max(fscore_dice_train)))+1)
# Out:
# Thershold is: 0.01
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.02
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.03
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.04
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.05
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.06
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.07
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.08
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.09
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.10
# current max fscore is: 0.2861314672984738
# thershold of the max fscore is: 0
# Thershold is: 0.11
# current max fscore is: 0.2861393503595338
# thershold of the max fscore is: 10
# Thershold is: 0.12
# current max fscore is: 0.2861393503595338
# thershold of the max fscore is: 10
# Thershold is: 0.13
# current max fscore is: 0.28616300214911555
# thershold of the max fscore is: 12
# Thershold is: 0.14
# current max fscore is: 0.28617877218119697
# thershold of the max fscore is: 13
# Thershold is: 0.15
# current max fscore is: 0.28621820486675664
# thershold of the max fscore is: 14
# Thershold is: 0.16
# current max fscore is: 0.28632867422049463
# thershold of the max fscore is: 15
# Thershold is: 0.17
# current max fscore is: 0.2866210398498731
# thershold of the max fscore is: 16
# Thershold is: 0.18
# current max fscore is: 0.28690607734806634
# thershold of the max fscore is: 17
# Thershold is: 0.19
# current max fscore is: 0.2873108523057346
# thershold of the max fscore is: 18
# Thershold is: 0.20
# current max fscore is: 0.2878204239988916
# thershold of the max fscore is: 19
# Thershold is: 0.21
# current max fscore is: 0.2885245901639344
# thershold of the max fscore is: 20
# Thershold is: 0.22
# current max fscore is: 0.2895228533980312
# thershold of the max fscore is: 21
# Thershold is: 0.23
# current max fscore is: 0.2912692178206711
# thershold of the max fscore is: 22
# Thershold is: 0.24
# current max fscore is: 0.2933793181432691
# thershold of the max fscore is: 23
# Thershold is: 0.25
# current max fscore is: 0.2963576631909728
# thershold of the max fscore is: 24
# Thershold is: 0.26
# current max fscore is: 0.300190983274495
# thershold of the max fscore is: 25
# Thershold is: 0.27
# current max fscore is: 0.30502293847782613
# thershold of the max fscore is: 26
# Thershold is: 0.28
# current max fscore is: 0.31120182494897347
# thershold of the max fscore is: 27
# Thershold is: 0.29
# current max fscore is: 0.31911289080548283
# thershold of the max fscore is: 28
# Thershold is: 0.30
# current max fscore is: 0.3278231680283742
# thershold of the max fscore is: 29
# Thershold is: 0.31
# current max fscore is: 0.33894750638967164
# thershold of the max fscore is: 30
# Thershold is: 0.32
# current max fscore is: 0.351779329133322
# thershold of the max fscore is: 31
# Thershold is: 0.33
# current max fscore is: 0.36786032424728315
# thershold of the max fscore is: 32
# Thershold is: 0.34
# current max fscore is: 0.38502034872867114
# thershold of the max fscore is: 33
# Thershold is: 0.35
# current max fscore is: 0.40463836477987414
# thershold of the max fscore is: 34
# Thershold is: 0.36
# current max fscore is: 0.42443783068783064
# thershold of the max fscore is: 35
# Thershold is: 0.37
# current max fscore is: 0.44834529854666433
# thershold of the max fscore is: 36
# Thershold is: 0.38
# current max fscore is: 0.4735401883029544
# thershold of the max fscore is: 37
# Thershold is: 0.39
# current max fscore is: 0.49918962722852517
# thershold of the max fscore is: 38
# Thershold is: 0.40
# current max fscore is: 0.5247991707696295
# thershold of the max fscore is: 39
# Thershold is: 0.41
# current max fscore is: 0.5572139303482587
# thershold of the max fscore is: 40
# Thershold is: 0.42
# current max fscore is: 0.5862956033676333
# thershold of the max fscore is: 41
# Thershold is: 0.43
# current max fscore is: 0.6137077406244226
# thershold of the max fscore is: 42
# Thershold is: 0.44
# current max fscore is: 0.6428849396808924
# thershold of the max fscore is: 43
# Thershold is: 0.45
# current max fscore is: 0.6705770017732915
# thershold of the max fscore is: 44
# Thershold is: 0.46
# current max fscore is: 0.6948778228966304
# thershold of the max fscore is: 45
# Thershold is: 0.47
# current max fscore is: 0.7163425857206471
# thershold of the max fscore is: 46
# Thershold is: 0.48
# current max fscore is: 0.7376859631542434
# thershold of the max fscore is: 47
# Thershold is: 0.49
# current max fscore is: 0.7560643663437676
# thershold of the max fscore is: 48
# Thershold is: 0.50
# current max fscore is: 0.7697119341563785
# thershold of the max fscore is: 49
# Thershold is: 0.51
# current max fscore is: 0.7883086915648235
# thershold of the max fscore is: 50
# Thershold is: 0.52
# current max fscore is: 0.7969436149657475
# thershold of the max fscore is: 51
# Thershold is: 0.53
# current max fscore is: 0.8066467985189198
# thershold of the max fscore is: 52
# Thershold is: 0.54
# current max fscore is: 0.811840888066605
# thershold of the max fscore is: 53
# Thershold is: 0.55
# current max fscore is: 0.8148427910490039
# thershold of the max fscore is: 54
# Thershold is: 0.56
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.57
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.58
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.59
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.60
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.61
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.62
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.63
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.64
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.65
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.66
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.67
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.68
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.69
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.70
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.71
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.72
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.73
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.74
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.75
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.76
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.77
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.78
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.79
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.80
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.81
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.82
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.83
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.84
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.85
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.86
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.87
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.88
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.89
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.90
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.91
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.92
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.93
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.94
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.95
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.96
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.97
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.98
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55
# Thershold is: 0.99
# current max fscore is: 0.8178827172440488
# thershold of the max fscore is: 55

# %%
test = pd.read_csv("test.tsv", sep="\t")

# %%
test
# Out:
#          idx                                          text_left  \
# 0          0  Elevator ( feat . Timbaland ) Flo Rida Mail On...
# 1          1  The Woodland Realm ( Extended Version ) Howard...
# 2          2  Extra Extra Credit Wiz Khalifa Flight School $...
# 3          3  Toyfriend ( feat . Wynter Gordon ) [ Continuou...
# 4          4  Dangerous ( feat . Sam Martin ) [ Robin Schulz...
# ...      ...                                                ...
# 10368  10368  lexar platinum ii 16gb sd sdhc memory card lex...
# 10369  10369  da-lite video spectra 1.5 advantage manual wit...
# 10370  10370  da-lite da-plex unframed rear projection scree...
# 10371  10371  rca cassette adapter mp3 accessories ah760r 12...
# 10372  10372  tp-link network tl-sg1024d 24 port gigabit des...
#
#                                               text_right  label
# 0      Money Right ( feat . Rick Ross & Brisco ) [ Ex...      0
# 1      The High Fells ( Extended Version ) The Hobbit...      0
# 2      Extra Extra Credit [ Explicit ] Wiz Khalifa 20...      1
# 3      Sound Of Letting Go ( Feat . Chris Willis ) Da...      0
# 4      Missing You ( Feat . Novel ; Continuous Mix Ve...      0
# ...                                                  ...    ...
# 10368  lexar lcf4gbbsbna200 platinum ii 4 gb 200x com...      0
# 10369  da-lite advantage manual with csr - projection...      0
# 10370  da-lite 27651 da-glas deluxe rear projection s...      0
# 10371  rca vca115 vhs-c cassette adapter blank media ...      0
# 10372  gigabit desktop switch 24port 24 10 100 1000 m...      1
#
# [10373 rows x 4 columns]

# %%
question1_test=test['text_left']
question2_test=test['text_right']
mark_test=test['label']

# %%
test_overlap=[]
test_jaccard=[]
test_dice=[]
for i in range(len(question1_test)):
    test_overlap.append(overlap(question1_test[i],question2_test[i]))
    test_jaccard.append(jaccard(question1_test[i],question2_test[i]))
    test_dice.append(dice(question1_test[i],question2_test[i]))

# %%
def calculate_is_duplicate(coefficient,thershold):
    mark=[]
    for i in range(len(coefficient)):
        if coefficient[i] >= thershold:
            mark.append(1)
        else:
            mark.append(0)
    return mark

# %%
mark_overlap_f_test=calculate_is_duplicate(test_overlap,overlap_threshold)
print("overlap threshold is:",overlap_threshold)
print("overlap coefficient fscore:")
print(f1_score(mark_test,mark_overlap_f_test,average='binary'))
# Out:
# overlap threshold is: 0.67
# overlap coefficient fscore:
# 0.7886685552407932

# %%
mark_jaccard_f_test=calculate_is_duplicate(test_jaccard,jaccard_threshold)
print("jaccard threshold is:",jaccard_threshold)
print("jaccard coefficient fscore:")
print(f1_score(mark_test,mark_jaccard_f_test,average='binary'))
# Out:
# jaccard threshold is: 0.52
# jaccard coefficient fscore:
# 0.8209173239848087

# %%
mark_dice_f_test=calculate_is_duplicate(test_dice,dice_threshold)
print("dice threshold is:",dice_threshold)
print("dice coefficient fscore:")
print(f1_score(mark_test,mark_dice_f_test,average='binary'))
# Out:
# dice threshold is: 0.56
# dice coefficient fscore:
# 0.8170731707317073

# %%
# use a classifier to predict the result
X_train=[]
X_test=[]
for i in range(len(question1)):
    co=(overlap_coefficient[i], jaccard_coefficient[i], dice_coefficient[i])
    X_train.append(co)
y_train=mark
for i in range(len(question1_test)):
    co=(test_overlap[i], test_jaccard[i], test_dice[i])
    X_test.append(co)
y_test=mark_test

# %%
#use KNeighbors Classifier
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=1)
model=knn.fit(X_train,y_train)
y_pred=knn.predict(X_test)
print("Test set predictions:\n{}".format(y_pred))
print("Test set score: {:.2f}".format(np.mean(y_pred == y_test)))
print("Test set score: {:.2f}".format(knn.score(X_test, y_test)))
# Out:
# Test set predictions:
# [0 1 1 ... 0 0 0]
# Test set score: 0.93
# Test set score: 0.93
