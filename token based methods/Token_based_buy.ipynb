# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import collections

# %%
def withStar(string):
  if string=='':
    return '';
  else:
    return '**'+string[:]+'**'

# %%
def grams(string,num)->list[str]:
    string=withStar(string)
    begin=len(string)-num;
    token=[];
    for i in range(begin+1):
        a=[];
        a=string[i:i+3]
        token.append(a);
    return token;

# %%
def overlap(string1,string2)->int:
    s1=grams(string1,3);
    s2=grams(string2,3);
    common_elements = list(set(s1).intersection(set(s2)));
    lc=len(common_elements);
    m=min(len(s1),len(s2));
    if m==0: 
        return 0;
    else:
        sim1=lc/m;
        return sim1;

# %%
def jaccard(string1,string2):
    s1=grams(string1,3);
    s2=grams(string2,3);
    common_elements = list(set(s1).intersection(set(s2)));
    lc=len(common_elements);
    union_elements=list(set(s1).union(set(s2)));
    lu=len(union_elements);
    if lu==0:
        return 0;
    else:
        sim2 = lc/lu;
        return sim2;

# %%
def dice(string1,string2):
    s1=grams(string1,3);
    s2=grams(string2,3);
    common_elements = list(set(s1).intersection(set(s2)));
    lc=len(common_elements);
    if len(s1)+len(s2)==0:
        return 0;
    else:
        sim3=2*lc/(len(s1)+len(s2));
        return sim3;

# %%
def accuracy(mark_real,mark_test):
    sum = 0
    for i in range(len(mark_real)):
        if mark_real[i]==mark_test[i]:
            sum=sum+1
        else:
            continue
    return sum/len(mark_test)

# %%
buy_train = pd.read_csv("buy_train.tsv", sep="\t")
buy_train
# Out:
#        idx                                          text_left  \
# 0        0  lg 24 ' lds4821ww semi integrated built in whi...
# 1        1  speck seethru clear hard shell case for macboo...
# 2        2  denon blu-ray disc dvd/cd player dvd3800bdci 1...
# 3        3  panasonic dect 6.0 expandable digital cordless...
# 4        4  sony silver minidv handycam camcorder dcrhc52 ...
# ...    ...                                                ...
# 5738  5738  sony silver cyber-shot digital camera dscw170 ...
# 5739  5739  panasonic nnsd377s stainless steel countertop ...
# 5740  5740  omnimount 42 ' 63 ' wishbone cantilever extra ...
# 5741  5741  samsung black dvd/vhs combo recorder dvdvr375 ...
# 5742  5742  logitech mx air rechargeable cordless air mous...
#
#                                              text_right  label
# 0              lg ldf6920bb fully integrated dishwasher      0
# 1     speck products seethru case for apple 13 ' mac...      0
# 2     denon dvd-2930ci dvd player dvd2930ci dvd + rw...      0
# 3     panasonic kx-tg1032s dual handset digital cord...      0
# 4        sony minidv head cleaner dvm12cld head cleaner      0
# ...                                                 ...    ...
# 5738  sony cyber-shot dsc-w300 digital camera 13.6 m...      0
# 5739  panasonic nn-c994s genius prestige convection ...      0
# 5740  sanus visionmount flat panel tv wall mount mf1...      0
# 5741  samsung dvd-v9800 dvd/vcr combo player w / 108...      0
# 5742  logitech cordless desktop mx 5000 laser 967562...      0
#
# [5743 rows x 4 columns]

# %%
question1=buy_train['text_left']
question2=buy_train['text_right']
mark=buy_train['label']

# %%
# #data processing
# question1_token=[]
# question2_token=[]
# for i in range(len(question1)):
#     question1_token.append(grams(question1[i],3))
# for i in range(len(question2)):
#     question2_token.append(grams(question2[i],3))
question1
# Out:
# 0       lg 24 ' lds4821ww semi integrated built in whi...
# 1       speck seethru clear hard shell case for macboo...
# 2       denon blu-ray disc dvd/cd player dvd3800bdci 1...
# 3       panasonic dect 6.0 expandable digital cordless...
# 4       sony silver minidv handycam camcorder dcrhc52 ...
#                               ...
# 5738    sony silver cyber-shot digital camera dscw170 ...
# 5739    panasonic nnsd377s stainless steel countertop ...
# 5740    omnimount 42 ' 63 ' wishbone cantilever extra ...
# 5741    samsung black dvd/vhs combo recorder dvdvr375 ...
# 5742    logitech mx air rechargeable cordless air mous...
# Name: text_left, Length: 5743, dtype: object

# %%
question2
# Out:
# 0                lg ldf6920bb fully integrated dishwasher
# 1       speck products seethru case for apple 13 ' mac...
# 2       denon dvd-2930ci dvd player dvd2930ci dvd + rw...
# 3       panasonic kx-tg1032s dual handset digital cord...
# 4          sony minidv head cleaner dvm12cld head cleaner
#                               ...
# 5738    sony cyber-shot dsc-w300 digital camera 13.6 m...
# 5739    panasonic nn-c994s genius prestige convection ...
# 5740    sanus visionmount flat panel tv wall mount mf1...
# 5741    samsung dvd-v9800 dvd/vcr combo player w / 108...
# 5742    logitech cordless desktop mx 5000 laser 967562...
# Name: text_right, Length: 5743, dtype: object

# %%
#calculate the overlap coefficient
overlap_coefficient=[]
for i in range(len(question1)):
    overlap_coefficient.append(overlap(question1[i],question2[i]))

# %%
#get the equal coefficient
equal_overlap=[]
for i in range(len(overlap_coefficient)):
    if mark[i]==1:
        equal_overlap.append(overlap_coefficient[i])
#         print("The two sentence is equal, overlap coefficient is:",overlap_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
#get the equal coefficient
inequal_overlap=[]
for i in range(len(overlap_coefficient)):
    if mark[i]==0:
        inequal_overlap.append(overlap_coefficient[i])
#         print("The two sentence is not equal, overlap coefficient is:",overlap_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
thershold=[]
for i in range(1,100):
    thershold.append(0.01*i)

# %%
accuracy_overlap_train=[]
for i in range(len(thershold)):
    mark_train_pred=[]
    for j in range(len(overlap_coefficient)):
        if overlap_coefficient[j] >= thershold[i]:
            mark_train_pred.append(1)
        else: mark_train_pred.append(0)
    accuracy_overlap_train.append(accuracy(mark,mark_train_pred))
    print("Thershold is: {:.2f}".format(thershold[i]))
    print("current max accuracy is: {}".format(max(accuracy_overlap_train)))
    print("thershold of the max accuracy is: {}".format(accuracy_overlap_train.index(max(accuracy_overlap_train))))#0.76
# Out:
# Thershold is: 0.01
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.02
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.03
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.04
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.05
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.06
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.07
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.08
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.09
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.10
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.11
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.12
# current max accuracy is: 0.10760926345115793
# thershold of the max accuracy is: 11
# Thershold is: 0.13
# current max accuracy is: 0.10778338847292356
# thershold of the max accuracy is: 12
# Thershold is: 0.14
# current max accuracy is: 0.1105693888211736
# thershold of the max accuracy is: 13
# Thershold is: 0.15
# current max accuracy is: 0.11335538916942364
# thershold of the max accuracy is: 14
# Thershold is: 0.16
# current max accuracy is: 0.1175343896917987
# thershold of the max accuracy is: 15
# Thershold is: 0.17
# current max accuracy is: 0.1238028904753613
# thershold of the max accuracy is: 16
# Thershold is: 0.18
# current max accuracy is: 0.12972314121539266
# thershold of the max accuracy is: 17
# Thershold is: 0.19
# current max accuracy is: 0.1382552672819084
# thershold of the max accuracy is: 18
# Thershold is: 0.20
# current max accuracy is: 0.14783214347901794
# thershold of the max accuracy is: 19
# Thershold is: 0.21
# current max accuracy is: 0.16123977015497126
# thershold of the max accuracy is: 20
# Thershold is: 0.22
# current max accuracy is: 0.17290614661326834
# thershold of the max accuracy is: 21
# Thershold is: 0.23
# current max accuracy is: 0.1871843983980498
# thershold of the max accuracy is: 22
# Thershold is: 0.24
# current max accuracy is: 0.2004179000522375
# thershold of the max accuracy is: 23
# Thershold is: 0.25
# current max accuracy is: 0.21521852690231585
# thershold of the max accuracy is: 24
# Thershold is: 0.26
# current max accuracy is: 0.2329792791224099
# thershold of the max accuracy is: 25
# Thershold is: 0.27
# current max accuracy is: 0.2528295316036914
# current max accuracy is: 0.3715450838241958
# thershold of the max accuracy is: 50
# Thershold is: 0.52
# current max accuracy is: 0.37954110898661564
# thershold of the max accuracy is: 51
# Thershold is: 0.53
# current max accuracy is: 0.38488664987405535
# thershold of the max accuracy is: 52
# Thershold is: 0.54
# current max accuracy is: 0.3863517060367454
# thershold of the max accuracy is: 53
# Thershold is: 0.55
# current max accuracy is: 0.38695163104611924
# thershold of the max accuracy is: 54
# Thershold is: 0.56
# current max accuracy is: 0.38695163104611924
# thershold of the max accuracy is: 54
# Thershold is: 0.57
# current max accuracy is: 0.39176543980037426
# thershold of the max accuracy is: 56
# Thershold is: 0.58
# current max accuracy is: 0.3919007184846505
# thershold of the max accuracy is: 57
# Thershold is: 0.59
# current max accuracy is: 0.407252440725244
# thershold of the max accuracy is: 58
# Thershold is: 0.60
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.61
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.62
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.63
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.64
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.65
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.66
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.67
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.68
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.69
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.70
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.71
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.72
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.73
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.74
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.75
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.76
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.77
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.78
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.79
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.80
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.81
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.82
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.83
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.84
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.85
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.86
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.87
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.88
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.89
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.90
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.91
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.92
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.93
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.94
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.95
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.96
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.97
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.98
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59
# Thershold is: 0.99
# current max accuracy is: 0.41358936484490394
# thershold of the max accuracy is: 59

# %%
# for i in range(len(overlap_coefficient)):
#     if overlap_coefficient[i] in equal_overlap:
#         plt.scatter(i,overlap_coefficient[i],color='r')
#     else:
#         plt.scatter(i,overlap_coefficient[i],color='b')
# ##thershold

# %%
# x=np.linspace(0,1,len(inequal_overlap))
# plt.plot(x,inequal_overlap)

# %%
#calculate the jaccard coefficient
jaccard_coefficient=[]
for i in range(len(question1)):
    jaccard_coefficient.append(jaccard(question1[i],question2[i]))

# %%
#get the equal coefficient
equal_jaccard=[]
for i in range(len(jaccard_coefficient)):
    if mark[i]==1:
        equal_jaccard.append(jaccard_coefficient[i])
#         print("The two sentence is equal, overlap coefficient is:",jaccard_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
#get the inequal coefficient
inequal_jaccard=[]
for i in range(len(jaccard_coefficient)):
    if mark[i]==0:
        inequal_jaccard.append(jaccard_coefficient[i])
#         print("The two sentence is not equal, overlap coefficient is:",jaccard_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
accuracy_jaccard_train=[]
for i in range(len(thershold)):
    mark_train_pred=[]
    for j in range(len(jaccard_coefficient)):
        if jaccard_coefficient[j] >= thershold[i]:
            mark_train_pred.append(1)
        else: mark_train_pred.append(0)
    accuracy_jaccard_train.append(accuracy(mark,mark_train_pred))
    print("Thershold is: {:.2f}".format(thershold[i]))
    print("current max accuracy is: {}".format(max(accuracy_jaccard_train)))
    print("thershold of the max accuracy is: {}".format(accuracy_jaccard_train.index(max(accuracy_jaccard_train))))#0.35
# Out:
# Thershold is: 0.01
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.02
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.03
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.04
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.05
# current max accuracy is: 0.1098728887341111
# thershold of the max accuracy is: 4
# Thershold is: 0.06
# current max accuracy is: 0.12293226536653318
# thershold of the max accuracy is: 5
# Thershold is: 0.07
# current max accuracy is: 0.14086714260839284
# thershold of the max accuracy is: 6
# Thershold is: 0.08
# current max accuracy is: 0.16872714609089326
# thershold of the max accuracy is: 7
# Thershold is: 0.09
# current max accuracy is: 0.216089152011144
# thershold of the max accuracy is: 8
# Thershold is: 0.10
# current max accuracy is: 0.27024203378025424
# thershold of the max accuracy is: 9
# Thershold is: 0.11
# current max accuracy is: 0.3374542921817865
# thershold of the max accuracy is: 10
# Thershold is: 0.12
# current max accuracy is: 0.4151140518892565
# thershold of the max accuracy is: 11
# Thershold is: 0.13
# current max accuracy is: 0.48894306111788266
# thershold of the max accuracy is: 12
# Thershold is: 0.14
# current max accuracy is: 0.5493644436705555
# thershold of the max accuracy is: 13
# Thershold is: 0.15
# current max accuracy is: 0.6021243252655406
# thershold of the max accuracy is: 14
# Thershold is: 0.16
# current max accuracy is: 0.6541877067734634
# thershold of the max accuracy is: 15
# Thershold is: 0.17
# current max accuracy is: 0.6975448371931047
# thershold of the max accuracy is: 16
# Thershold is: 0.18
# current max accuracy is: 0.7290614661326833
# thershold of the max accuracy is: 17
# Thershold is: 0.19
# current max accuracy is: 0.7623193452899182
# thershold of the max accuracy is: 18
# Thershold is: 0.20
# current max accuracy is: 0.7870450983806373
# thershold of the max accuracy is: 19
# Thershold is: 0.21
# current max accuracy is: 0.8039352254919032
# thershold of the max accuracy is: 20
# Thershold is: 0.22
# current max accuracy is: 0.8220442277555284
# thershold of the max accuracy is: 21
# Thershold is: 0.23
# current max accuracy is: 0.8364966045620755
# thershold of the max accuracy is: 22
# Thershold is: 0.24
# current max accuracy is: 0.8530384816298102
# thershold of the max accuracy is: 23
# Thershold is: 0.25
# current max accuracy is: 0.8650531081316385
# thershold of the max accuracy is: 24
# Thershold is: 0.26
# current max accuracy is: 0.8713216089152012
# thershold of the max accuracy is: 25
# Thershold is: 0.27
# current max accuracy is: 0.87933135991642
# thershold of the max accuracy is: 26
# Thershold is: 0.28
# current max accuracy is: 0.8850774856346857
# thershold of the max accuracy is: 27
# Thershold is: 0.29
# current max accuracy is: 0.8873411109176389
# thershold of the max accuracy is: 28
# Thershold is: 0.30
# current max accuracy is: 0.8904753613094202
# thershold of the max accuracy is: 29
# Thershold is: 0.31
# current max accuracy is: 0.8925648615706077
# thershold of the max accuracy is: 30
# Thershold is: 0.32
# current max accuracy is: 0.8950026118753265
# thershold of the max accuracy is: 31
# Thershold is: 0.33
# current max accuracy is: 0.8958732369841547
# thershold of the max accuracy is: 32
# Thershold is: 0.34
# current max accuracy is: 0.8958732369841547
# thershold of the max accuracy is: 32
# Thershold is: 0.35
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.36
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.37
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.38
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.39
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.40
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.41
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.42
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.43
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.44
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.45
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.46
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.47
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.48
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.49
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.50
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.51
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.52
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.53
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.54
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.55
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.56
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.57
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.58
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.59
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.60
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.61
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.62
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.63
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.64
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.65
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.66
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.67
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.68
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.69
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.70
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.71
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.72
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.73
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.74
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.75
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.76
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.77
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.78
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.79
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.80
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.81
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.82
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.83
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.84
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.85
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.86
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.87
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.88
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.89
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.90
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.91
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.92
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.93
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.94
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.95
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.96
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.97
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.98
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34
# Thershold is: 0.99
# current max accuracy is: 0.8962214870276859
# thershold of the max accuracy is: 34

# %%
fscore_jaccard_train=[]
for i in range(len(thershold)):
    mark_train_pred=[]
    for j in range(len(jaccard_coefficient)):
        if jaccard_coefficient[j] >= thershold[i]:
            mark_train_pred.append(1)
        else: mark_train_pred.append(0)
    fscore_jaccard_train.append(f1_score(mark,mark_train_pred,average='binary'))
    print("Thershold is: {:.2f}".format(thershold[i]))
    print("current max accuracy is: {}".format(max(fscore_jaccard_train)))
    print("thershold of the max accuracy is: {}".format(fscore_jaccard_train.index(max(fscore_jaccard_train))))#0.20
# Out:
# Thershold is: 0.01
# current max accuracy is: 0.19374115426953925
# thershold of the max accuracy is: 0
# Thershold is: 0.02
# current max accuracy is: 0.19374115426953925
# thershold of the max accuracy is: 0
# Thershold is: 0.03
# current max accuracy is: 0.19374115426953925
# thershold of the max accuracy is: 0
# Thershold is: 0.04
# current max accuracy is: 0.19374115426953925
# thershold of the max accuracy is: 0
# Thershold is: 0.05
# current max accuracy is: 0.19419924337957123
# thershold of the max accuracy is: 4
# Thershold is: 0.06
# current max accuracy is: 0.19575283410506147
# thershold of the max accuracy is: 5
# Thershold is: 0.07
# current max accuracy is: 0.19824504387390318
# thershold of the max accuracy is: 6
# Thershold is: 0.08
# current max accuracy is: 0.20353687020353686
# thershold of the max accuracy is: 7
# Thershold is: 0.09
# current max accuracy is: 0.21211060553027652
# thershold of the max accuracy is: 8
# Thershold is: 0.10
# current max accuracy is: 0.22172701949860724
# thershold of the max accuracy is: 9
# Thershold is: 0.11
# current max accuracy is: 0.23701624222979747
# thershold of the max accuracy is: 10
# Thershold is: 0.12
# current max accuracy is: 0.25702278257022787
# thershold of the max accuracy is: 11
# Thershold is: 0.13
# current max accuracy is: 0.2758450530471256
# thershold of the max accuracy is: 12
# Thershold is: 0.14
# current max accuracy is: 0.2905701754385965
# thershold of the max accuracy is: 13
# Thershold is: 0.15
# current max accuracy is: 0.30399025281754494
# thershold of the max accuracy is: 14
# Thershold is: 0.16
# current max accuracy is: 0.32356948228882837
# thershold of the max accuracy is: 15
# Thershold is: 0.17
# current max accuracy is: 0.33524684270952926
# thershold of the max accuracy is: 16
# Thershold is: 0.18
# current max accuracy is: 0.33955857385398985
# thershold of the max accuracy is: 17
# Thershold is: 0.19
# current max accuracy is: 0.34907010014306145
# thershold of the max accuracy is: 18
# Thershold is: 0.20
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.21
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.22
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.23
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.24
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.25
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.26
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.27
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.28
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.29
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.30
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.31
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.32
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.33
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.34
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.35
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.36
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.37
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.38
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.39
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.40
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.41
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.42
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.43
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.44
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.45
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.46
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.47
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.48
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.49
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.50
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.51
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.52
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.53
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.54
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.55
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.56
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.57
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.58
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.59
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.60
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.61
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.62
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.63
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.64
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.65
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.66
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.67
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.68
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.69
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.70
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.71
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.72
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.73
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.74
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.75
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.76
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.77
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.78
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.79
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.80
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.81
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.82
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.83
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.84
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.85
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.86
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.87
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.88
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.89
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.90
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.91
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.92
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.93
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.94
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.95
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.96
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.97
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.98
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19
# Thershold is: 0.99
# current max accuracy is: 0.3539355520338088
# thershold of the max accuracy is: 19

# %%
# for i in range(len(jaccard_coefficient)):
#     if jaccard_coefficient[i] in inequal_jaccard:
#         plt.scatter(i,jaccard_coefficient[i],color='r')
#     else:
#         plt.scatter(i,jaccard_coefficient[i],color='b')
# # worse than overlap coeffient

# %%
#calculate the dice's coefficient
dice_coefficient=[]
for i in range(len(question1)):
    dice_coefficient.append(dice(question1[i],question2[i]))

# %%
#get the equal coefficient
equal_dice=[]
for i in range(len(dice_coefficient)):
    if mark[i]==1:
        equal_dice.append(dice_coefficient[i])
#         print("The two sentence is equal, overlap coefficient is:",dice_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
#get the inequal coefficient
inequal_dice=[]
for i in range(len(dice_coefficient)):
    if mark[i]==0:
        inequal_dice.append(dice_coefficient[i])
#         print("The two sentence is not equal, overlap coefficient is:",dice_coefficient[i])
#         print(question1[i])
#         print(question2[i])
#         print('-'*50)

# %%
accuracy_dice_train=[]
for i in range(len(thershold)):
    mark_train_pred=[]
    for j in range(len(dice_coefficient)):
        if dice_coefficient[j] >= thershold[i]:
            mark_train_pred.append(1)
        else: mark_train_pred.append(0)
    accuracy_dice_train.append(accuracy(mark,mark_train_pred))
    print("Thershold is: {:.2f}".format(thershold[i]))
    print("current max accuracy is: {}".format(max(accuracy_dice_train)))
    print("thershold of the max accuracy is: {}".format(accuracy_dice_train.index(max(accuracy_dice_train))))#0.42
# Out:
# Thershold is: 0.01
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.02
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.03
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.04
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0.05
# current max accuracy is: 0.10726101340762667
# thershold of the max accuracy is: 0
# Thershold is: 0
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.43
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.44
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.45
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.46
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.47
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.48
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.49
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.50
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.51
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.52
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.53
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.54
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.55
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.56
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.57
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.58
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.59
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.60
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.61
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.62
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.63
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.64
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.65
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.66
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.67
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.68
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.69
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.70
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.71
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.72
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.73
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.74
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.75
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.76
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.77
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.78
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.79
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.80
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.81
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.82
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.83
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.84
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.85
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.86
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.87
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.88
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.89
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.90
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.91
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.92
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.93
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.94
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.95
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.96
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.97
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.98
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41
# Thershold is: 0.99
# current max accuracy is: 0.8979627372453421
# thershold of the max accuracy is: 41

# %%
fscore_dice_train=[]
for i in range(len(thershold)):
    mark_train_pred=[]
    for j in range(len(dice_coefficient)):
        if dice_coefficient[j] >= thershold[i]:
            mark_train_pred.append(1)
        else: mark_train_pred.append(0)
    fscore_dice_train.append(f1_score(mark,mark_train_pred,average='binary'))
    print("Thershold is: {:.2f}".format(thershold[i]))
    print("current max accuracy is: {}".format(max(fscore_dice_train)))
    print("thershold of the max accuracy is: {}".format(fscore_dice_train.index(max(fscore_dice_train))))#0.29
# Out:
# Thershold is: 0.01
# current max accuracy is: 0.19374115426953925
# thershold of the max accuracy is: 0
# Thershold is: 0.02
# current max accuracy is: 0.19374115426953925
# thershold of the max accuracy is: 0
# Thershold is: 0.03
# current max accuracy is: 0.19374115426953925
# thershold of the max accuracy is: 0
# Thershold is: 0.04
# current max accuracy is: 0.19374115426953925
# thershold of the max accuracy is: 0
# Thershold is: 0.05
# current max accuracy is: 0.19374115426953925
# thershold of the max accuracy is: 0
# Thershold is: 0.06
# current max accuracy is: 0.19374115426953925
# thershold of the max accuracy is: 0
# Thershold is: 0.07
# current max accuracy is: 0.19380210791253738
# thershold of the max accuracy is: 6
# Thershold is: 0.08
# current max accuracy is: 0.19429112127424697
# thershold of the max accuracy is: 7
# Thershold is: 0.09
# current max accuracy is: 0.19529262086513996
# thershold of the max accuracy is: 8
# Thershold is: 0.10
# current max accuracy is: 0.19653179190751446
# thershold of the max accuracy is: 9
# Thershold is: 0.11
# current max accuracy is: 0.19895799413871704
# thershold of the max accuracy is: 10
# Thershold is: 0.12
# current max accuracy is: 0.2028262676641729
# thershold of the max accuracy is: 11
# Thershold is: 0.13
# current max accuracy is: 0.20852593733949665
# thershold of the max accuracy is: 12
# Thershold is: 0.14
# current max accuracy is: 0.21384315808107632
# thershold of the max accuracy is: 13
# Thershold is: 0.15
# current max accuracy is: 0.22242851838098773
# thershold of the max accuracy is: 14
# Thershold is: 0.16
# current max accuracy is: 0.2327400743203599
# thershold of the max accuracy is: 15
# Thershold is: 0.17
# current max accuracy is: 0.24379139072847686
# thershold of the max accuracy is: 16
# Thershold is: 0.18
# current max accuracy is: 0.25713653463155567
# thershold of the max accuracy is: 17
# Thershold is: 0.19
# current max accuracy is: 0.2697919158096149
# thershold of the max accuracy is: 18
# Thershold is: 0.20
# current max accuracy is: 0.28393135725429014
# thershold of the max accuracy is: 19
# Thershold is: 0.21
# current max accuracy is: 0.29509116409537167
# thershold of the max accuracy is: 20
# Thershold is: 0.22
# current max accuracy is: 0.30693977376948944
# thershold of the max accuracy is: 21
# Thershold is: 0.23
# current max accuracy is: 0.31730126920507684
# thershold of the max accuracy is: 22
# Thershold is: 0.24
# current max accuracy is: 0.3307550644567219
# thershold of the max accuracy is: 23
# Thershold is: 0.25
# current max accuracy is: 0.3360064153969527
# thershold of the max accuracy is: 24
# Thershold is: 0.26
# current max accuracy is: 0.33799126637554583
# thershold of the max accuracy is: 25
# Thershold is: 0.27
# current max accuracy is: 0.33799126637554583
# thershold of the max accuracy is: 25
# Thershold is: 0.28
# current max accuracy is: 0.33799126637554583
# thershold of the max accuracy is: 25
# Thershold is: 0.29
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.30
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.31
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.32
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.33
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.34
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.35
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.36
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.37
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.38
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.39
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.40
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.41
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.42
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.43
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.44
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.45
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.46
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.47
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.48
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.49
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.50
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.51
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.52
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.53
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.54
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.55
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.56
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.57
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.58
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.59
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.60
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.61
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.62
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.63
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.64
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.65
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.66
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.67
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.68
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.69
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.70
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.71
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.72
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.73
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.74
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.75
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.76
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.77
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.78
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.79
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.80
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.81
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.82
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.83
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.84
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.85
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.86
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.87
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.88
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.89
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.90
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.91
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.92
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.93
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.94
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.95
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.96
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.97
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.98
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28
# Thershold is: 0.99
# current max accuracy is: 0.3393541324575807
# thershold of the max accuracy is: 28

# %%
# for i in range(len(dice_coefficient)):
#     if dice_coefficient[i] in inequal_dice:
#         plt.scatter(i,dice_coefficient[i],color='r')
#     else:
#         plt.scatter(i,dice_coefficient[i],color='b')

# %%
# # use equal weight in each coefficient
# coefficient=[]
# for i in range(len(mark)):
#     coefficient.append(overlap_coefficient[i]/3+jaccard_coefficient[i]/3+dice_coefficient[i]/3)

# %%
# for i in range(len(coefficient)):
#     if mark[i]==1:
#         plt.scatter(i,coefficient[i],color='r')
#     else:
#         plt.scatter(i,coefficient[i],color='b')
# # same as overlap coefficient

# %%
buy_test = pd.read_csv("buy_test.tsv", sep="\t")

# %%
buy_test
# Out:
#        idx                                          text_left  \
# 0        0  sony pink cyber-shot 7.2 megapixel digital cam...
# 1        1  lg 2.0 cu . ft. over-the-range white microwave...
# 2        2  panasonic black 8.5 ' portable dvd player dvdl...
# 3        3  sony bravia theater black micro system davis50...
# 4        4  panasonic dect 6.0 expandable digital cordless...
# ...    ...                                                ...
# 1911  1911  nikon coolpix s210 plum 8.1 megapixels compact...
# 1912  1912  lg 2.0 cu . ft. over-the-range black microwave...
# 1913  1913  lg dlex7177rm cherry red xl capacity electric ...
# 1914  1914  sanus 15 ' to 40 ' flat panel black tv wall mo...
# 1915  1915  toshiba black portable dvd player sdp71s 7 ' w...
#
#                                              text_right  label
# 0     olympus fe-360 digital camera pink 226540 8 me...      0
# 1     maytag 2.0 cu . ft. over-the-range microwave oven      0
# 2     toshiba sd-p71s portable dvd player toshiba sd...      0
# 3     sony bravia dav-is50 / b home theater system d...      1
# 4     panasonic kx-tg9342t cordless phone 1 x phone ...      0
# ...                                                 ...    ...
# 1911  nikon coolpix s610 digital camera midnight bla...      0
# 1912       lg 2.0 cu.ft . over the range microwave oven      1
# 1913                        lgs new electric steamdryer      0
# 1914  omnimount ultra low profile ulpt-l flat panel ...      0
# 1915  toshiba sd-p91s portable dvd player toshiba sd...      0
#
# [1916 rows x 4 columns]

# %%
question1_test=buy_test['text_left']
question2_test=buy_test['text_right']
mark_test=buy_test['label']

# %%
test_overlap=[]
test_jaccard=[]
test_dice=[]
for i in range(len(question1_test)):
    test_overlap.append(overlap(question1_test[i],question2_test[i]))
    test_jaccard.append(jaccard(question1_test[i],question2_test[i]))
    test_dice.append(dice(question1_test[i],question2_test[i]))

# %%
# #calculate the overlap coefficient
# coefficient_test=[]
# for i in range(len(question1_test)):
#     coefficient_test.append(overlap(question1_test[i],question2_test[i])/3+jaccard(question1_test[i],question2_test[i])/3+dice(question1_test[i],question2_test[i])/3)

# %%
#     coefficient_test.append(overlap(question1_test[i],question2_test[i])/3+jaccard(question1_test[i],question2_test[i])/3+dice(question1_test[i],question2_test[i])/3)

# %%
# for i in range(len(coefficient_test)):
#     if mark_test[i]==1:
#         plt.scatter(i,coefficient_test[i],color='r')
#     else:
#         plt.scatter(i,coefficient_test[i],color='b')

# %%
def calculate_is_duplicate(coefficient,thershold):
    mark=[]
    for i in range(len(coefficient)):
        if coefficient[i] >= thershold:
            mark.append(1)
        else:
            mark.append(0)
    return mark

# %%
mark_overlap_acc_test=calculate_is_duplicate(test_overlap,0.76)
print(accuracy(mark_test,mark_overlap_acc_test))
print('-'*50)
mark_overlap_f_test=calculate_is_duplicate(test_overlap,0.60)
print("fscore:")
print(f1_score(mark_test,mark_overlap_f_test,average='binary'))
# Out:
# 0.8997912317327766
# --------------------------------------------------
# fscore:
# 0.3964757709251101

# %%
mark_jaccard_acc_test=calculate_is_duplicate(test_jaccard,0.35)
print(accuracy(mark_test,mark_jaccard_acc_test))
print('-'*50)
mark_jaccard_f_test=calculate_is_duplicate(test_jaccard,0.20)
print("fscore:")
print(f1_score(mark_test,mark_jaccard_f_test,average='binary'))
# Out:
# 0.8924843423799582
# --------------------------------------------------
# fscore:
# 0.3195084485407066

# %%
mark_dice_acc_test=calculate_is_duplicate(test_dice,0.42)
print(accuracy(mark_test,mark_dice_acc_test))
print('-'*50)
mark_dice_f_test=calculate_is_duplicate(test_dice,0.29)
print("fscore:")
print(f1_score(mark_test,mark_dice_f_test,average='binary'))
# Out:
# 0.8961377870563675
# --------------------------------------------------
# fscore:
# 0.3094462540716612

# %%
# def acc(mark_real,mark_test):
#     sum = 0
#     for i in range(len(mark_real)):
#         if mark_real[i]==mark_test[i]:
#             sum=sum+1
#         else:
#             continue
#     return sum/len(mark_test)

# %%
# acc(mark_test,mark_calculate)

# %%
# use a classifier to predict the result
X_train=[]
X_test=[]
for i in range(len(question1)):
    co=(overlap_coefficient[i], jaccard_coefficient[i], dice_coefficient[i])
    X_train.append(co)
y_train=mark
for i in range(len(question1_test)):
    co=(test_overlap[i], test_jaccard[i], test_dice[i])
    X_test.append(co)
y_test=mark_test

# %%
#use KNeighbors Classifier
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=1)
model=knn.fit(X_train,y_train)
y_pred=knn.predict(X_test)
print("Test set predictions:\n{}".format(y_pred))
print("Test set score: {:.2f}".format(np.mean(y_pred == y_test)))
print("Test set score: {:.2f}".format(knn.score(X_test, y_test)))
